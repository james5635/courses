# %% [markdown]
# Graph with no slope and no x value
# y = 5

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax-xmin)
x = np.linspace(xmin,xmax,  points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin, ymax])
plt.plot([xmin,xmax], [0,0], 'b')
plt.plot([0,0], [ymin, ymax], 'b')

plt.plot([xmin,xmax], [5,5],'r')
plt.show()

# %% [markdown]
# Linear Graph
# y = x

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax-xmin)
x = np.linspace(xmin,xmax,  points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin, ymax])
plt.plot([xmin,xmax], [0,0], 'b')
plt.plot([0,0], [ymin, ymax], 'b')

plt.plot(x,x,'r')
plt.show()

# %% [markdown]
# Quadratic Graph
# y = x**2

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax-xmin)
x = np.linspace(xmin,xmax,  points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin, ymax])
plt.plot([xmin,xmax], [0,0], 'b')
plt.plot([0,0], [ymin, ymax], 'b')

plt.plot(x,x**2,'r')
plt.show()

# %% [markdown]
# Cubic Graph
# y = x**3

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4 * (xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], "b")
plt.plot([0, 0], [ymin, ymax], "b")

# plt.plot(x,x**3,'r')
plt.plot(x, x**3 - 3 * x**2 - 3 * x + 4, "r")
plt.show()

# %% [markdown]
# Quartic Graph
# y = x**4

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4 * (xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], "b")
plt.plot([0, 0], [ymin, ymax], "b")

# plt.plot(x,x**4,'r')
plt.plot(x,x**4,'r')
plt.show()

# %% [markdown]
# Quintic graphs
# y = x**5

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4 * (xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], "b")
plt.plot([0, 0], [ymin, ymax], "b")

# plt.plot(x,x**4,'r')
plt.plot(x,x**5,'r')
plt.show()

# %% [markdown]
# Absolute value graph
# y = |x|

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4 * (xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], "b")
plt.plot([0, 0], [ymin, ymax], "b")

# plt.plot(x,x**4,'r')
plt.plot(x,abs(x),'r')
plt.show()

# %% [markdown]
# Square root graphs
# $ y = \sqrt{x} $

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4 * (xmax - xmin)
x = np.linspace(0, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], "b")
plt.plot([0, 0], [ymin, ymax], "b")

# plt.plot(x,x**4,'r')
plt.plot(x, np.sqrt(x))
# plt.plot(x, -np.sqrt(x))
plt.show()

# %% [markdown]
# Square root with rational exponent
# $ y = x^{1/2}  $

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4 * (xmax - xmin)
x = np.linspace(0, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], "b")
plt.plot([0, 0], [ymin, ymax], "b")

# plt.plot(x,x**4,'r')
# plt.plot(x, np.power(x, 1/2))
plt.plot(x, x**(1/2))
plt.show()

# %% [markdown]
# Cube root of x
# $ y = x^{1/3} $

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4 * (xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], "b")
plt.plot([0, 0], [ymin, ymax], "b")

# plt.plot(x,x**4,'r')
# plt.plot(x, np.power(x, 1/3))
plt.plot(x, np.cbrt(x))
# plt.plot(x, x**(1/3))
plt.show()

# %% [markdown]
# Floor Function
# $ y = \lfloor x \rfloor $

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4 * (xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], "b")
plt.plot([0, 0], [ymin, ymax], "b")

import math
for x in range(points):
    plt.plot([0.25 * x  - 10], [math.floor(0.25*x)-10], 'ro')

plt.show()

# %% [markdown]
# Exponential Function
# $ y = 2^{x} $

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4 * (xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], "b")
plt.plot([0, 0], [ymin, ymax], "b")

plt.plot(x, 2 ** x)

plt.show()
